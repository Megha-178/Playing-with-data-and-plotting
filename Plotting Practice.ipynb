# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline                     # to prevent pop up
# Out:
# UsageError: unrecognized arguments: # to prevent pop up

# %% [markdown]
# # **Line charts**

# %%
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(yield_apples)

# %%
plt.plot(yield_apples);  # to prevent unintended output like above add semicolon

# %% [markdown]
# Customizing **axis**

# %%
years = [2010, 2011, 2012, 2013, 2014, 2015]
yield_apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931]

# %%
plt.plot(years, yield_apples);

# %%
#axis labels
plt.plot(years, yield_apples)
plt.xlabel('year')
plt.ylabel("yield_apples");

# %%
years = range(2000, 2012)
apples = [0.895, 0.91, 0.919, 0.926, 0.929, 0.931, 0.934, 0.936, 0.937, 0.9375, 0.9372, 0.939]
oranges = [0.962, 0.941, 0.930, 0.923, 0.918, 0.908, 0.907, 0.904, 0.901, 0.898, 0.9, 0.896, ]

# %%
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('years')
plt.ylabel('yiels tons per hecatre')
# Out:
# Text(0, 0.5, 'yiels tons per hecatre')

# %%
plt.plot(years, apples)
plt.plot(years, oranges)
plt.xlabel('years')
plt.ylabel('yiels tons per hecatre')
plt.title("Crop Yields in Kanto")
plt.legend(['Apples','Oranges'])    #legends will differentiate the lines, plt.legend(["a","b"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-3642dfb100b1> in <cell line: 5>()
#       3 plt.xlabel('years')
#       4 plt.ylabel('yiels tons per hecatre')
# ----> 5 plt.title("Crop Yields in Kanto")
#       6 plt.legend(['Apples','Oranges'])    #legends will differentiate the lines, plt.legend(["a","b"])
#       7 plt.show()
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # **Line Marks**
#
# go for matplolib.markers for more

# %%
plt.plot(years, apples, marker='o')
plt.plot(years, oranges, marker='x')
plt.xlabel('years')
plt.ylabel('yiels tons per hecatre')
plt.legend(['Apples','Oranges'])
plt.title('Crop Yields')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-c686a7aa5839> in <cell line: 6>()
#       4 plt.ylabel('yiels tons per hecatre')
#       5 plt.legend(['Apples','Oranges'])
# ----> 6 plt.title('Crop Yields')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# **Styling**
# **color or c:** Set the color of the line (supported colors)
# **linestyle or ls**: Choose between a solid or dashed line
# **linewidth or lw**: Set the width of a line
# **markersize or ms**: Set the size of markers
# markeredgecolor or mec: Set the edge color for markers
# **markeredgewidth or mew**: Set the edge width for markers
# **markerfacecolor or mfc**: Set the fill color for markers
# **alpha**: Opacity of the plot

# %%
plt.plot(years, apples, marker='s', c='b', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(years, oranges, marker='o', c='r', ls='--', lw=3, ms=10, alpha=.5)

plt.xlabel('Year')  #fmt {'marker,line,colour}
plt.ylabel('Yield (tons per hectare)')


plt.legend(['Apples', 'Oranges']);

# %%
sns.set_style('darkgrid') # sns_set_style('whitegrid")

# %%
plt.plot(years, apples, marker='s', c='b', ls='-', lw=2, ms=8, mew=2, mec='navy')
plt.plot(years, oranges, marker='o', c='r', ls='--', lw=3, ms=10, alpha=.5)

plt.xlabel('Year')  #fmt {'marker,line,colour}
plt.ylabel('Yield (tons per hectare)')

plt.legend(['Apples', 'Oranges']);

# %%
plt.plot(years,'or');

# %% [markdown]
# # **Scatter plot**   relation between two variables in a 2 dimensional grid

# %%
#matplotlib.rcparams == can also edit default styles directly by modifying the matplotlib.rcParams dictionary

# %%
flowers_df = sns.load_dataset("iris")  # load dataset inbuilt
flowers_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
flowers_df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width);

# %% [markdown]
# # **Adding Hues**
# hue=flowers_df.species,
#  s= size

# %%
sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width, hue=flowers_df.species, s=50)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# customizing seaborn figures

# %%
plt.figure(figsize=(5,5))

sns.scatterplot(x=flowers_df.sepal_length, y=flowers_df.sepal_width,
                hue=flowers_df.species, s=50)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %% [markdown]
# # **Histogram**

# %%
flowers_df=sns.load_dataset('iris')
flowers_df.sepal_width
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
flowers_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
plt.hist(flowers_df.sepal_width);

# %% [markdown]
# controlling the no;of bins and sizes

# %%
import numpy as np
np.arange(2,5,0.25)   #start frm 2 the end number is before 5 in the intervals of 0.25
# Out:
# array([2.  , 2.25, 2.5 , 2.75, 3.  , 3.25, 3.5 , 3.75, 4.  , 4.25, 4.5 ,
#        4.75])

# %%
plt.hist(flowers_df.sepal_width, bins=np.arange(2,5,0.25), color='y');

# %%
setosa_df = flowers_df[flowers_df.species == 'setosa']
versicolor_df = flowers_df[flowers_df.species == 'versicolor']
virginica_df = flowers_df[flowers_df.species == 'virginica']

# %%
plt.hist(setosa_df.sepal_width, bins=np.arange(2,5,0.25));
plt.hist(versicolor_df.sepal_width, bins= np.arange(2,5,0.25));
plt.legend(['Setosa','versicolor']);

# %% [markdown]
# One over the other histo=stacked

# %%
plt.hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],
         bins=np.arange(2,5,0.25),
         stacked=True);

# %% [markdown]
# # **Bar Chart**

# %%
years = range(2000, 2006)
apples = [0.35, 0.6, 0.9, 0.8, 0.65, 0.8]
oranges = [0.4, 0.8, 0.9, 0.7, 0.6, 0.8]

# %%
plt.bar(years, apples,)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.bar(years, oranges)
plt.plot(years,oranges,"o--r");

# %% [markdown]
# # **Bar plots with averages**

# %%
tips_df=sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
bill_avg_df=tips_df.groupby('day')[['total_bill']].mean()

# %%
plt.bar(bill_avg_df.index, bill_avg_df.total_bill);

# %%
tips_df=sns.load_dataset("tips")
tips_df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(x='day',y='total_bill',data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x='day',y='total_bill',hue='sex', data=tips_df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # **Heat Map**

# %%
flight_df=sns.load_dataset('flights')
flight_df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flight_df=sns.load_dataset('flights').pivot("month", "year", "passengers")
# Out:
# <ipython-input-9-8ffbcc768296>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flight_df=sns.load_dataset('flights').pivot("month", "year", "passengers")

# %%
flight_df
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flight_df);

# %%
sns.heatmap(flight_df, fmt='d', annot=True, cmap='Blues'); #annot gives th labels of each
plt.figure(figsize=(15,7))

# %% [markdown]
# # **Image**

# %%
from urllib.request import urlretrieve

# %%
urlretrieve('https://i.imgur.com/SkPbq.jpg','chart.jpg')
# Out:
# ('chart.jpg', <http.client.HTTPMessage at 0x7e0b77f63430>)

# %%
from PIL import Image  #PIL is the image module

# %%
img=Image.open('chart.jpg')

# %%
plt,plt.imshow(img); #imshow is used for displaying image

# %% [markdown]
# Plotting multiple charts in a grid

# %%
plt.subplots(2,3)
sns.set_style('darkgrid')
plt.tight_layout(pad=2)   #for spacing

# %%
fig,axes=plt.subplots(2,3, figsize=(16,8))

axes[0,0].plot(years, apples, 's-b')
axes[0,0].plot(years, oranges, 'o--r')
axes[0,0].set_xlabel('Year')
axes[0,0].set_ylabel('Yield (tons per hectare)')
axes[0,0].legend(['Apples', 'Oranges']);
axes[0,0].set_title('Crop Yields in Kanto')


axes[0,1].set_title('Sepal Length vs. Sepal Width')
sns.scatterplot(x=flowers_df.sepal_length,
                y=flowers_df.sepal_width,
                hue=flowers_df.species,
                s=100,
                ax=axes[0,1])

axes[0,2].set_title('Distribution of Sepal Width')
axes[0,2].hist([setosa_df.sepal_width, versicolor_df.sepal_width, virginica_df.sepal_width],
         bins=np.arange(2, 5, 0.25),
         stacked=True);

axes[1,0].set_title('Restaurant bills')
sns.barplot(x='day', y='total_bill', hue='sex', data=tips_df, ax=axes[1,0]);

axes[1,1].set_title('Flight traffic')
sns.heatmap(flight_df, cmap='Blues', ax=axes[1,1]);

axes[1,2].set_title('Data Science Meme')
axes[1,2].imshow(img)
axes[1,2].grid(False)
axes[1,2].set_xticks([])
axes[1,2].set_yticks([])
plt.tight_layout(pad=2);

# %% [markdown]
# # **Pair plots with seaborn**
